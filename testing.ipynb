# %%
print("This is new notebook here")
list1 = ["milk", "juice", "mocha", "coffee", "tea"]
for i in list1:
    print(i)

# %%
import requests
response_data = requests.get("https://fakerapi.it/api/v2/companies?_quantity=5")
print(response_data.json())
